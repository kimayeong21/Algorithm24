# %% [markdown]
# ##### 예제 4.10 정렬을 이용한 k번재 작은 수 찾기
#   1) 문제 정의 (MD) : 리스트에서 k번째로 작은 항목을 찾아라. 단, 리스트는 정렬되어 있지 않다.
#   2) 알고리즘 설명  (MD) : 리스트를 sort 함수를 통해 정렬하고, 정렬된 리스트에서 k-1의 인덱스를 가지고 있는 값을 반환한다(k번째 값).
#   3) 손으로 푼 예제 (MD, 이미지 삽입) : ![4_Quest10 손으로 푼 예제.jpg](<attachment:4_Quest10 손으로 푼 예제.jpg>)
#   4) 코드 개요(입력 변수, 출력, 함수 설명) (MD) :
#   ###### 4.0. 함수 명 : kth_smallest_sort
#   ###### 4.1. 입력 변수 : 리스트와 출력할 n번째의 위치(n-1)
#   ###### 4.2. 출력 : 정렬된 리스트의 n-1번째 인덱스 값
#   ###### 4.3. 함수 설명 : A.sort를 통해 리스트를 정렬시키고, return A[k-1]을 통해 k번째의 원소 값을 리턴시킨다.
#   5) 코드 (PY,C) :
#   6) 테스트 코드  (PY,C) , 입력을 바꾸어서 :
#   7) 수행 결과 (MD, 결과 캡처하여 이미지로 삽입) : ![4_Quest10.png](attachment:4_Quest10.png)
#   8) 복잡도 분석 (MD) : 따로 반복문이나 조건문에 거치는 것 없이 리턴으로 값이 반환되므로 O(1)일 것이라고 생각합니다.
#   9) 협력 내용(조별, 팀별) :
#   ###### 아영 : 4.3 4.5 4.6
#   ###### 대환 선배님 : 4.7 4.8
#   ###### 은선 : 4.1 4.2
#   ###### 효원 : 4.4 4.10 4.11(+4.12) //4.10의 내용이 적은 것과 4.11이나 4.12와 연결되어 있기에 선택 되었습니다.
# ###### Github 반드시 업로드
# ###### 추후 과제 종합점수에 추가 반영 (일목요연하게 내용을 잘 정리할 것)

# %%
#5) 코드
def kth_smallest_sort(A, k):
    A.sort()
    return A[k-1]

#6) 테스트 코드
A=[7, 10, 4, 3, 20, 15]
A.sort()
A.sort(reverse=True)

B = sorted(A, reverse=True)

print("[정렬기법] 3번째 작은 수: ", kth_smallest_sort(A, 3))
print("[정렬기법] 6번째 작은 수: ", kth_smallest_sort(B, 6))
# Out:
# [정렬기법] 3번째 작은 수:  7
# [정렬기법] 6번째 작은 수:  20

# %%
#5) 코드
def kth_smallest_sort(A, k):
    A.sort()
    return A[k-1]

#6) 테스트 코드
A=[12, 3, 5, 7, 4, 19, 26, 23, 15]
print("입력 리스트 =", A)

print("[정렬기법] 3번째 작은 수: ", kth_smallest_sort(A, 3))
print("[정렬기법] 6번째 작은 수: ", kth_smallest_sort(A, 6))
# Out:
# 입력 리스트 = [12, 3, 5, 7, 4, 19, 26, 23, 15]
# [정렬기법] 3번째 작은 수:  5
# [정렬기법] 6번째 작은 수:  15
